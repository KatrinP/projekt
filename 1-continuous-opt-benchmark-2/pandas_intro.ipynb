# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# import matplotlib
# matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
df = pd.read_csv("hs_cont.txt", index_col="Iteration", delimiter=';')

# %%
df.plot()

# %%
max_value = df.max()['fitness']
row = df.loc[df['fitness'] == max_value]
row
# Out:
#            fitness vectors
# Iteration
# 33           0.001   0.001

# %%
df[df['fitness'].apply(lambda x: x > 0.002)] = 0.001
row
# Out:
#            fitness vectors
# Iteration
# 33           0.001   0.001

# %%
df.plot()

# %%
df.median()
# Out:
# fitness    0.000014
# dtype: float64

# %%
df[df['fitness'].apply(lambda x: x > 0.0002)] = 0.0001

# %%
df.plot.area()

# %%
df.plot.bar()

# %%
df.plot.barh()

# %%
df.plot.box()

# %%
df.plot.density()

# %%
df.plot.hist()

# %%
df.plot.kde()

# %%
df.plot.line()

# %%
df.plot.scatter(x='fitness', y='fitness')

# %%
df = pd.read_csv("hs_cont.txt", delimiter=';')
df[df['fitness'].apply(lambda x: x > 0.002)] = 0.0001

# %%
# df.plot.scatter(x='Iteration', y='fitness')
ax = df.plot(kind='scatter', x='fitness', y='Iteration',color='DarkBlue', label='Group 1')
# df.fitness = df.fitness * 0.1
df.plot(kind='scatter', x='fitness', y='Iteration',color='DarkGreen', label='Group 2', ax=ax)
plt.ylim(-50, 1050)
plt.xlim(-0.0005, 0.0005)
plt.grid()
# plt.legend()
